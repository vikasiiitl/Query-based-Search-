# %%
# %pip install pymupdf
# %pip install pymilvus
# %pip install pytesseract
# %pip install langchain-community
# %pip install langchain_community
# %pip install sentence-transformers
# Out:
# Requirement already satisfied: pymupdf in d:\research\.venv\lib\site-packages (1.25.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pymilvus in d:\research\.venv\lib\site-packages (2.5.8)
# Requirement already satisfied: setuptools>69 in d:\research\.venv\lib\site-packages (from pymilvus) (80.4.0)
# Requirement already satisfied: grpcio<=1.67.1,>=1.49.1 in d:\research\.venv\lib\site-packages (from pymilvus) (1.67.1)
# Requirement already satisfied: protobuf>=3.20.0 in d:\research\.venv\lib\site-packages (from pymilvus) (6.30.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in d:\research\.venv\lib\site-packages (from pymilvus) (1.1.0)
# Requirement already satisfied: ujson>=2.0.0 in d:\research\.venv\lib\site-packages (from pymilvus) (5.10.0)
# Requirement already satisfied: pandas>=1.2.4 in d:\research\.venv\lib\site-packages (from pymilvus) (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in d:\research\.venv\lib\site-packages (from pandas>=1.2.4->pymilvus) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\research\.venv\lib\site-packages (from pandas>=1.2.4->pymilvus) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\research\.venv\lib\site-packages (from pandas>=1.2.4->pymilvus) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\research\.venv\lib\site-packages (from pandas>=1.2.4->pymilvus) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\research\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pytesseract in d:\research\.venv\lib\site-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in d:\research\.venv\lib\site-packages (from pytesseract) (24.2)
# Requirement already satisfied: Pillow>=8.0.0 in d:\research\.venv\lib\site-packages (from pytesseract) (11.2.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain-community in d:\research\.venv\lib\site-packages (0.3.24)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.59 in d:\research\.venv\lib\site-packages (from langchain-community) (0.3.59)
# Requirement already satisfied: langchain<1.0.0,>=0.3.25 in d:\research\.venv\lib\site-packages (from langchain-community) (0.3.25)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\research\.venv\lib\site-packages (from langchain-community) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in d:\research\.venv\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in d:\research\.venv\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\research\.venv\lib\site-packages (from langchain-community) (3.11.18)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in d:\research\.venv\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in d:\research\.venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in d:\research\.venv\lib\site-packages (from langchain-community) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in d:\research\.venv\lib\site-packages (from langchain-community) (0.3.42)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in d:\research\.venv\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in d:\research\.venv\lib\site-packages (from langchain-community) (2.2.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\research\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\research\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in d:\research\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\research\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\research\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in d:\research\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\research\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\research\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\research\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in d:\research\.venv\lib\site-packages (from langchain<1.0.0,>=0.3.25->langchain-community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\research\.venv\lib\site-packages (from langchain<1.0.0,>=0.3.25->langchain-community) (2.11.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\research\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in d:\research\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in d:\research\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-community) (4.13.2)
# Requirement already satisfied: jsonpointer>=1.9 in d:\research\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.59->langchain-community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\research\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\research\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\research\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in d:\research\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: anyio in d:\research\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: certifi in d:\research\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in d:\research\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in d:\research\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (3.10)
# Requirement already satisfied: h11>=0.16 in d:\research\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\research\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.25->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\research\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.25->langchain-community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\research\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.25->langchain-community) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\research\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\research\.venv\lib\site-packages (from requests<3,>=2->langchain-community) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\research\.venv\lib\site-packages (from requests<3,>=2->langchain-community) (2.4.0)
# Requirement already satisfied: greenlet>=1 in d:\research\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\research\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in d:\research\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain_community in d:\research\.venv\lib\site-packages (0.3.24)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.59 in d:\research\.venv\lib\site-packages (from langchain_community) (0.3.59)
# Requirement already satisfied: langchain<1.0.0,>=0.3.25 in d:\research\.venv\lib\site-packages (from langchain_community) (0.3.25)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\research\.venv\lib\site-packages (from langchain_community) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in d:\research\.venv\lib\site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in d:\research\.venv\lib\site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\research\.venv\lib\site-packages (from langchain_community) (3.11.18)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in d:\research\.venv\lib\site-packages (from langchain_community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in d:\research\.venv\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in d:\research\.venv\lib\site-packages (from langchain_community) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in d:\research\.venv\lib\site-packages (from langchain_community) (0.3.42)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in d:\research\.venv\lib\site-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in d:\research\.venv\lib\site-packages (from langchain_community) (2.2.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\research\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\research\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in d:\research\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\research\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\research\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in d:\research\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\research\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\research\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\research\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in d:\research\.venv\lib\site-packages (from langchain<1.0.0,>=0.3.25->langchain_community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\research\.venv\lib\site-packages (from langchain<1.0.0,>=0.3.25->langchain_community) (2.11.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\research\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in d:\research\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain_community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in d:\research\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain_community) (4.13.2)
# Requirement already satisfied: jsonpointer>=1.9 in d:\research\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.59->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\research\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\research\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\research\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in d:\research\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.23.0)
# Requirement already satisfied: anyio in d:\research\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (4.9.0)
# Requirement already satisfied: certifi in d:\research\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in d:\research\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in d:\research\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (3.10)
# Requirement already satisfied: h11>=0.16 in d:\research\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\research\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.25->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\research\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.25->langchain_community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\research\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.25->langchain_community) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\research\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\research\.venv\lib\site-packages (from requests<3,>=2->langchain_community) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\research\.venv\lib\site-packages (from requests<3,>=2->langchain_community) (2.4.0)
# Requirement already satisfied: greenlet>=1 in d:\research\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.2.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\research\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in d:\research\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import re
import fitz  # PyMuPDF

# === Configuration ===
PDF_INPUT_DIR = "./pdf_inputs"
OUTPUT_DIR = "./pdf_extracted_text"
os.makedirs(OUTPUT_DIR, exist_ok=True)

def create_output_folder(title):
    folder_name = re.sub(r'[^a-zA-Z0-9]+', '_', title).strip('_')
    folder_path = os.path.join(OUTPUT_DIR, folder_name)
    os.makedirs(folder_path, exist_ok=True)
    return folder_path

def save_text(content, path):
    with open(path, 'w', encoding='utf-8') as f:
        f.write(content)

def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    return full_text

def process_pdf(pdf_path):
    filename = os.path.basename(pdf_path)
    title = os.path.splitext(filename)[0]
    print(f"Processing: {filename}")

    folder = create_output_folder(title)

    # Extract and save text
    text = extract_text_from_pdf(pdf_path)
    save_text(text, os.path.join(folder, 'document.md'))

if __name__ == '__main__':
    pdf_files = [f for f in os.listdir(PDF_INPUT_DIR) if f.lower().endswith(".pdf")]
    for pdf_file in pdf_files:
        try:
            full_path = os.path.join(PDF_INPUT_DIR, pdf_file)
            process_pdf(full_path)
        except Exception as err:
            print(f"Error processing {pdf_file}: {err}")
# Out:
# Processing: 1_Explaining Relationships Among Research Papers 2024.pdf
# Processing: 2305.08487v2.pdf
# Processing: 2305.08828v2.pdf
# Processing: 2405.10936v2.pdf
# Processing: 2502.09457v1.pdf
# Processing: 2502.17956v1.pdf
# Processing: 2503.10267v2.pdf
# Processing: chatcite.pdf
# Processing: compressive summarizer .pdf
# Processing: Research Papers_ update .pdf

# %%
from pymilvus import connections, utility
from dotenv import load_dotenv

MILVUS_URI = os.getenv("MILVUS_URI")
TOKEN = os.getenv("MILVUS_TOKEN")
# Disconnect any existing 'default' connection first
connections.disconnect("default")

# Then connect with the new URI and token
connections.connect("default", uri=MILVUS_URI, token=TOKEN)

collection_name = "knowledge_base"
dim = 384  # Dimension of the embedding model

# Check and reset collection if it already exists
if utility.has_collection(collection_name):
    utility.drop_collection(collection_name)

# %%
from pymilvus import FieldSchema, DataType, CollectionSchema, Collection
fields = [
    FieldSchema(name="id", dtype=DataType.INT64, is_primary=True, auto_id=True),
    FieldSchema(name="content", dtype=DataType.VARCHAR, max_length=10000),
    FieldSchema(name="embedding", dtype=DataType.FLOAT_VECTOR, dim=dim),
]
schema = CollectionSchema(fields, description="Knowledge base embeddings")
collection = Collection(name=collection_name, schema=schema)

# %%
import os
from langchain.docstore.document import Document

EXTRACTED_TEXT_DIR = "./pdf_extracted_text"

def load_documents_from_extracted_text(folder_path=EXTRACTED_TEXT_DIR):
    documents = []

    for subfolder in os.listdir(folder_path):
        subfolder_path = os.path.join(folder_path, subfolder)
        if not os.path.isdir(subfolder_path):
            continue

        md_file_path = os.path.join(subfolder_path, "document.md")
        if not os.path.exists(md_file_path):
            continue

        try:
            with open(md_file_path, "r", encoding="utf-8") as f:
                text = f.read().strip()
                if text:
                    documents.append(Document(
                        page_content=text,
                        metadata={"source": subfolder}
                    ))
        except Exception as e:
            print(f"Error reading {md_file_path}: {e}")

    return documents

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings  # updated import

documents = load_documents_from_extracted_text("./pdf_extracted_text")
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)
chunks = splitter.split_documents(documents)

embedding_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
contents = [chunk.page_content for chunk in chunks]
embeddings = embedding_model.embed_documents(contents)

collection.insert([contents, embeddings])
collection.flush()

# Create an index for efficient vector search
index_params = {"index_type": "AUTOINDEX", "metric_type": "IP", "params": {}}
collection.create_index("embedding", index_params)
collection.load()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File d:\Research\.venv\Lib\site-packages\langchain_community\embeddings\huggingface.py:84, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      83 try:
# ---> 84     import sentence_transformers
#      86 except ImportError as exc:
#
# ModuleNotFoundError: No module named 'sentence_transformers'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 11
#       8 splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)
#       9 chunks = splitter.split_documents(documents)
# ---> 11 embedding_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
#      12 contents = [chunk.page_content for chunk in chunks]
#      13 embeddings = embedding_model.embed_documents(contents)
#
# File d:\Research\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:224, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     222     warned = True
#     223     emit_warning()
# --> 224 return wrapped(self, *args, **kwargs)
#
# File d:\Research\.venv\Lib\site-packages\langchain_community\embeddings\huggingface.py:87, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      84     import sentence_transformers
#      86 except ImportError as exc:
# ---> 87     raise ImportError(
#      88         "Could not import sentence_transformers python package. "
#      89         "Please install it with `pip install sentence-transformers`."
#      90     ) from exc
#      92 self.client = sentence_transformers.SentenceTransformer(
#      93     self.model_name, cache_folder=self.cache_folder, **self.model_kwargs
#      94 )
#
# ImportError: Could not import sentence_transformers python package. Please install it with `pip install sentence-transformers`.
